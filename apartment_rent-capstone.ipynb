# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df_original = pd.read_csv('apartment_dotcom.csv')

# %%
df = df_original.copy()

# %%
df.head()
# Out:
#    Unnamed: 0                                                url listingid  \
# 0           0  https://www.apartments.com/2372-beckwith-dr-in...   ze0jqwy
# 1           1  https://www.apartments.com/the-marott-apartmen...   cqv6bmf
# 2           2  https://www.apartments.com/trails-at-lakeside-...   p38me3t
# 3           3  https://www.apartments.com/7491-n-shadeland-av...   s34dq64
# 4           4  https://www.apartments.com/nice-3-bedroom-ranc...   n669z9m
#
#         ZIP     Monthly Rent  Bedrooms Bathrooms        Square Feet walkScore  \
# 0 46218.000             $751      2 bd      1 ba          679 sq ft        25
# 1 46208.000  $1,185 - $1,645  1 - 2 bd  1 - 2 ba  609 - 1,092 sq ft        54
# 2 46220.000  $1,193 - $2,805  1 - 3 bd  1 - 2 ba  594 - 1,246 sq ft        20
# 3 46250.000           $1,795      3 bd      2 ba        2,500 sq ft        54
# 4 46237.000           $1,095      3 bd      1 ba        1,439 sq ft        29
#
#   transitScore       Deposit  latitude  longitude   Pet           neighborhood
# 0           33  $705 deposit    39.801    -86.126 0.000  Martindale-Brightwood
# 1           52           NaN    39.805    -86.156   NaN    Mapleton Fall Creek
# 2           12           NaN    39.856    -86.101   NaN           Millersville
# 3           33           NaN    39.890    -86.045   NaN        I-69 Fall Creek
# 4           32           NaN    39.722    -86.121   NaN     University Heights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    704 non-null    int64
#  1   url           704 non-null    object
#  2   listingid     693 non-null    object
#  3   ZIP           693 non-null    float64
#  4   Monthly Rent  680 non-null    object
#  5   Bedrooms      680 non-null    object
#  6   Bathrooms     680 non-null    object
#  7   Square Feet   664 non-null    object
#  8   walkScore     693 non-null    object
#  9   transitScore  693 non-null    object
#  10  Deposit       162 non-null    object
#  11  latitude      693 non-null    float64
#  12  longitude     693 non-null    float64
#  13  Pet           36 non-null     float64
#  14  neighborhood  693 non-null    object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 82.6+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       ZIP  latitude  longitude    Pet
# count     704.000   693.000   693.000    693.000 36.000
# mean      351.500 46220.284    39.789    -86.144  0.000
# std       203.372    30.687     0.075      0.091  0.000
# min         0.000 46038.000    39.627    -86.344  0.000
# 25%       175.750 46204.000    39.752    -86.201  0.000
# 50%       351.500 46222.000    39.790    -86.144  0.000
# 75%       527.250 46237.000    39.838    -86.086  0.000
# max       703.000 46298.000    39.946    -85.950  0.000

# %%
df.shape
# Out:
# (704, 15)

# %%
df.duplicated().value_counts()
# Out:
# False    704
# dtype: int64

# %%
#df.drop_duplicates(keep="first", inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'url', 'listingid', 'ZIP', 'Monthly Rent', 'Bedrooms',
#        'Bathrooms', 'Square Feet', 'walkScore', 'transitScore', 'Deposit',
#        'latitude', 'longitude', 'Pet', 'neighborhood'],
#       dtype='object')

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.head()
# Out:
#                                                  url listingid       ZIP  \
# 0  https://www.apartments.com/2372-beckwith-dr-in...   ze0jqwy 46218.000
# 1  https://www.apartments.com/the-marott-apartmen...   cqv6bmf 46208.000
# 2  https://www.apartments.com/trails-at-lakeside-...   p38me3t 46220.000
# 3  https://www.apartments.com/7491-n-shadeland-av...   s34dq64 46250.000
# 4  https://www.apartments.com/nice-3-bedroom-ranc...   n669z9m 46237.000
#
#       Monthly Rent  Bedrooms Bathrooms        Square Feet walkScore  \
# 0             $751      2 bd      1 ba          679 sq ft        25
# 1  $1,185 - $1,645  1 - 2 bd  1 - 2 ba  609 - 1,092 sq ft        54
# 2  $1,193 - $2,805  1 - 3 bd  1 - 2 ba  594 - 1,246 sq ft        20
# 3           $1,795      3 bd      2 ba        2,500 sq ft        54
# 4           $1,095      3 bd      1 ba        1,439 sq ft        29
#
#   transitScore       Deposit  latitude  longitude   Pet           neighborhood
# 0           33  $705 deposit    39.801    -86.126 0.000  Martindale-Brightwood
# 1           52           NaN    39.805    -86.156   NaN    Mapleton Fall Creek
# 2           12           NaN    39.856    -86.101   NaN           Millersville
# 3           33           NaN    39.890    -86.045   NaN        I-69 Fall Creek
# 4           32           NaN    39.722    -86.121   NaN     University Heights

# %%
dict = {'listingid': 'listing_id', 'ZIP' : 'zipcode', 'Monthly Rent' : 'monthly_rent', 'Bedrooms':'bedrooms',
       'Bathrooms': 'bathrooms', 'Square Feet': 'square_feet', 'walkScore':'walk_score', 
       'transitScore': 'transit_score', 'Deposit': 'deposit',
       'Pet': 'pet'}


df.rename(columns=dict, inplace=True)

# %%
for col in df.columns:
    print(col)
    print('--'*20)
    print(df[col].value_counts())
    print('##'*20)
# Out:
# url
# ----------------------------------------
# https://www.apartments.com/sebring-court-indianapolis-in/z2q88qw/                               1
# https://www.apartments.com/3-br-1-bath-house-3912-aurora-st-indianapolis-in/xvz3ljn/            1
# https://www.apartments.com/920-n-alabama-st-indianapolis-in/1br13f7/                            1
# https://www.apartments.com/3-br-1-bath-house-3-bedroom-near-butler-indianapolis-in/rx007s0/     1
# https://www.apartments.com/7126-parklake-pl-indianapolis-in/k4ljt28/                            1
#                                                                                                ..
# https://www.apartments.com/woodhaven-park-apartment-indianapolis-in/vz17sre/                    1
# https://www.apartments.com/8110-meadow-ln-indianapolis-in/7pz858y/                              1
# https://www.apartments.com/coventry-park-village-indianapolis-in/h7wlcb2/                       1
# https://www.apartments.com/3-br-1-bath-house-1660-centennial-avenue-indianapolis-in/lvstw0e/    1
# https://www.apartments.com/3-br-2-bath-house-538-buffalo-ridge-ct-indianapolis-in/hzmk1k2/      1
# Name: url, Length: 704, dtype: int64
# ########################################
# listing_id
# ----------------------------------------
# dyc1zyh    1
# 8036fh3    1
# 8kphrb0    1
# eq34gym    1
# kvse798    1
#           ..
# d5tcfbk    1
# 59jzkgn    1
# jdmbfq7    1
# ec0t2cq    1
# z2q88qw    1
# Name: listing_id, Length: 693, dtype: int64
# ########################################
# zipcode
# ----------------------------------------
# 46202.000    49
# 46227.000    36
# 46201.000    36
# 46203.000    35
# 46220.000    31
# 46237.000    31
# 46254.000    30
# 46268.000    25
# 46219.000    25
# 46229.000    24
# 46205.000    24
# 46204.000    23
# 46240.000    21
# 46218.000    20
# 46235.000    20
# 46208.000    20
# 46222.000    19
# 46239.000    19
# 46224.000    18
# 46226.000    18
# 46214.000    17
# 46260.000    17
# 46217.000    16
# 46234.000    15
# 46113.000    14
# 46221.000    14
# 46250.000    13
# 46228.000     8
# 46241.000     8
# 46225.000     6
# 46256.000     6
# 46280.000     5
# 46123.000     5
# 46107.000     4
# 46236.000     4
# 46142.000     4
# 46216.000     3
# 46038.000     3
# 46231.000     2
# 46259.000     2
# 46290.000     1
# 46168.000     1
# 46298.000     1
# Name: zipcode, dtype: int64
# ########################################
# monthly_rent
# ----------------------------------------
# $1,695             16
# $1,595             11
# $1,795             10
# $1,550              8
# $1,495              8
#                    ..
# $850 - $875         1
# $920 - $1,145       1
# $940 - $1,335       1
# $720 - $1,130       1
# $1,507 - $2,971     1
# Name: monthly_rent, Length: 494, dtype: int64
# ########################################
# bedrooms
# ----------------------------------------
# 3 bd             199
# 1 - 3 bd          99
# 1 - 2 bd          91
# 2 bd              82
# Studio - 2 bd     52
# 1 bd              40
# 4 bd              38
# Studio - 3 bd     24
# Studio bd         13
# 1 - 4 bd          11
# 2 - 3 bd          10
# Studio - 1 bd      8
# Studio - 4 bd      6
# 5 bd               6
# 2 - 4 bd           1
# Name: bedrooms, dtype: int64
# ########################################
# bathrooms
# ----------------------------------------
# 1 ba            185
# 1 - 2 ba        175
# 2 ba            124
# 2.5 ba           59
# 1 - 2.5 ba       43
# 1.5 ba           33
# 1 - 1.5 ba       30
# 3 ba             10
# 1 - 3 ba          8
# 1.5 - 2.5 ba      4
# 1.5 - 2 ba        2
# 1 - 4 ba          2
# 3.5 ba            2
# 4 ba              1
# 1 - 3.5 ba        1
# 0.5 ba            1
# Name: bathrooms, dtype: int64
# ########################################
# square_feet
# ----------------------------------------
# 288 - 864 sq ft      8
# 470 - 1,140 sq ft    7
# 1,400 sq ft          6
# 1,000 sq ft          6
# 2,200 sq ft          6
#                     ..
# 555 - 1,500 sq ft    1
# 896 sq ft            1
# 632 - 1,266 sq ft    1
# 571 - 896 sq ft      1
# 675 - 1,100 sq ft    1
# Name: square_feet, Length: 542, dtype: int64
# ########################################
# walk_score
# ----------------------------------------
# 11    15
# 7     14
# 6     14
# 9     13
# 54    13
#       ..
# 81     1
# 91     1
# 86     1
# 85     1
# 95     1
# Name: walk_score, Length: 100, dtype: int64
# ########################################
# transit_score
# ----------------------------------------
# 0     171
# 30     36
# 38     25
# 32     24
# 39     24
# 34     24
# 35     22
# 23     21
# 25     21
# 29     20
# 37     19
# 33     19
# 27     17
# 28     17
# 36     15
# 40     15
# 22     15
# 31     12
# 52     11
# 41     10
# 21      9
# 26      9
# 67      9
# 68      8
# 24      8
# 53      7
# 49      7
# 18      7
# 20      7
# -       6
# 46      5
# 59      5
# 55      4
# 64      4
# 54      4
# 48      4
# 50      4
# 43      4
# 61      3
# 19      3
# 15      3
# 51      3
# 47      3
# 42      3
# 57      3
# 17      3
# 58      3
# 44      2
# 65      2
# 62      2
# 14      2
# 11      2
# 56      2
# 63      2
# 60      1
# 16      1
# 12      1
# Name: transit_score, dtype: int64
# ########################################
# deposit
# ----------------------------------------
# $250 deposit      13
# $200 deposit      12
# $500 deposit       9
# $300 deposit       8
# $1,500 deposit     7
#                   ..
# $1,750 deposit     1
# $1,825 deposit     1
# $1,350 deposit     1
# $2,085 deposit     1
# $1,998 deposit     1
# Name: deposit, Length: 74, dtype: int64
# ########################################
# latitude
# ----------------------------------------
# 39.779    3
# 39.925    3
# 39.910    3
# 39.768    2
# 39.696    2
#          ..
# 39.787    1
# 39.653    1
# 39.769    1
# 39.732    1
# 39.873    1
# Name: latitude, Length: 671, dtype: int64
# ########################################
# longitude
# ----------------------------------------
# -86.134    3
# -86.164    3
# -86.138    3
# -86.244    2
# -85.990    2
#           ..
# -86.311    1
# -86.148    1
# -86.005    1
# -85.978    1
# -86.150    1
# Name: longitude, Length: 672, dtype: int64
# ########################################
# pet
# ----------------------------------------
# 0.000    36
# Name: pet, dtype: int64
# ########################################
# neighborhood
# ----------------------------------------
# Indianapolis         63
# Near Eastside        32
# Circle City          25
# East Warren          24
# Far Eastside         23
#                      ..
# Bayhead Village       1
# Southeast Warren      1
# Meadows               1
# West Indianapolis     1
# Warren Park           1
# Name: neighborhood, Length: 105, dtype: int64
# ########################################

# %%
df.head(2)
# Out:
#                                                  url listing_id   zipcode  \
# 0  https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy 46218.000
# 1  https://www.apartments.com/the-marott-apartmen...    cqv6bmf 46208.000
#
#       monthly_rent  bedrooms bathrooms        square_feet walk_score  \
# 0             $751      2 bd      1 ba          679 sq ft         25
# 1  $1,185 - $1,645  1 - 2 bd  1 - 2 ba  609 - 1,092 sq ft         54
#
#   transit_score       deposit  latitude  longitude   pet  \
# 0            33  $705 deposit    39.801    -86.126 0.000
# 1            52           NaN    39.805    -86.156   NaN
#
#             neighborhood
# 0  Martindale-Brightwood
# 1    Mapleton Fall Creek

# %%
df.zipcode = df.zipcode.astype(str).str.extract('(\d+)')

# %%
df.head()
# Out:
#                                                  url listing_id zipcode  \
# 0  https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy   46218
# 1  https://www.apartments.com/the-marott-apartmen...    cqv6bmf   46208
# 2  https://www.apartments.com/trails-at-lakeside-...    p38me3t   46220
# 3  https://www.apartments.com/7491-n-shadeland-av...    s34dq64   46250
# 4  https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m   46237
#
#       monthly_rent  bedrooms bathrooms        square_feet walk_score  \
# 0             $751      2 bd      1 ba          679 sq ft         25
# 1  $1,185 - $1,645  1 - 2 bd  1 - 2 ba  609 - 1,092 sq ft         54
# 2  $1,193 - $2,805  1 - 3 bd  1 - 2 ba  594 - 1,246 sq ft         20
# 3           $1,795      3 bd      2 ba        2,500 sq ft         54
# 4           $1,095      3 bd      1 ba        1,439 sq ft         29
#
#   transit_score       deposit  latitude  longitude   pet  \
# 0            33  $705 deposit    39.801    -86.126 0.000
# 1            52           NaN    39.805    -86.156   NaN
# 2            12           NaN    39.856    -86.101   NaN
# 3            33           NaN    39.890    -86.045   NaN
# 4            32           NaN    39.722    -86.121   NaN
#
#             neighborhood
# 0  Martindale-Brightwood
# 1    Mapleton Fall Creek
# 2           Millersville
# 3        I-69 Fall Creek
# 4     University Heights

# %%
df.shape
# Out:
# (704, 14)

# %%
df.sample(5)
# Out:
#                                                    url listing_id zipcode  \
# 263  https://www.apartments.com/726-n-denny-st-indp...    9mx2gw7   46201
# 596  https://www.apartments.com/gardens-of-canal-co...    n2n426m   46202
# 355  https://www.apartments.com/6121-jester-ct-indi...    vm0l3rd   46254
# 270  https://www.apartments.com/6417-amber-valley-l...    9e1dkn6   46237
# 432  https://www.apartments.com/the-elliott-at-coll...    wpztblk   46268
#
#         monthly_rent  bedrooms bathrooms        square_feet walk_score  \
# 263             $750      1 bd      1 ba          784 sq ft         51
# 596  $1,094 - $1,568  1 - 2 bd  1 - 2 ba  875 - 1,311 sq ft         78
# 355           $1,670      3 bd      2 ba        1,478 sq ft         10
# 270           $1,640      3 bd      2 ba        1,491 sq ft          9
# 432           $1,034  1 - 2 bd  1 - 2 ba    792 - 968 sq ft         68
#
#     transit_score         deposit  latitude  longitude  pet  \
# 263            35             NaN    39.777    -86.100  NaN
# 596            55             NaN    39.777    -86.166  NaN
# 355            21  $1,670 deposit    39.866    -86.264  NaN
# 270             0             NaN    39.675    -86.045  NaN
# 432             0             NaN    39.914    -86.214  NaN
#
#            neighborhood
# 263       Near Eastside
# 596           The Canal
# 355  Snacks Guion Creek
# 270            Galludet
# 432        College Park

# %%
df.head(2)
# Out:
#                                                  url listing_id zipcode  \
# 0  https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy   46218
# 1  https://www.apartments.com/the-marott-apartmen...    cqv6bmf   46208
#
#       monthly_rent  bedrooms bathrooms        square_feet walk_score  \
# 0             $751      2 bd      1 ba          679 sq ft         25
# 1  $1,185 - $1,645  1 - 2 bd  1 - 2 ba  609 - 1,092 sq ft         54
#
#   transit_score       deposit  latitude  longitude   pet  \
# 0            33  $705 deposit    39.801    -86.126 0.000
# 1            52           NaN    39.805    -86.156   NaN
#
#             neighborhood
# 0  Martindale-Brightwood
# 1    Mapleton Fall Creek

# %%
df.monthly_rent.str.contains('-')
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 699    False
# 700     True
# 701    False
# 702     True
# 703    False
# Name: monthly_rent, Length: 704, dtype: object

# %%
df.monthly_rent.str.contains('-').value_counts()
# Out:
# False    365
# True     315
# Name: monthly_rent, dtype: int64

# %%
df_dirty_1 = df[df.monthly_rent.str.contains('-')== True]
df_dirty_2 = df[df.monthly_rent.str.contains('-')== True]
df_dirty_1.sample(5)
# Out:
#                                                    url listing_id zipcode  \
# 702  https://www.apartments.com/the-continental-tow...    lskywte   46204
# 409  https://www.apartments.com/overlook-at-valley-...    7k8mpny   46237
# 14   https://www.apartments.com/forest-ridge-indian...    52ygmmm   46260
# 339  https://www.apartments.com/apartments-marten-c...    xgz8q4q   46226
# 426  https://www.apartments.com/block-apartments-in...    y7ghflr   46204
#
#         monthly_rent  bedrooms bathrooms          square_feet walk_score  \
# 702  $1,020 - $1,528  1 - 2 bd  1 - 2 ba    550 - 1,100 sq ft         96
# 409    $964 - $1,405  1 - 3 bd  1 - 2 ba    723 - 1,452 sq ft         56
# 14     $931 - $1,420  1 - 4 bd  1 - 2 ba    790 - 1,487 sq ft          4
# 339      $675 - $925  1 - 2 bd      1 ba      800 - 980 sq ft         54
# 426  $1,565 - $2,690  1 - 2 bd  1 - 2 ba  1,043 - 1,793 sq ft         94
#
#     transit_score       deposit  latitude  longitude  pet   neighborhood
# 702            67           NaN    39.773    -86.158  NaN   Indianapolis
# 409            23           NaN    39.668    -86.080  NaN  South Emerson
# 14             28           NaN    39.893    -86.201  NaN  Crooked Creek
# 339             0  $675 deposit    39.834    -86.030  NaN   Far Eastside
# 426            68  $500 deposit    39.768    -86.160  NaN    Circle City

# %%
df_dirty_1.monthly_rent.str.split('-').str[0].str.replace(',', '').str.extract('(\d+)')
# Out:
#         0
# 1    1185
# 2    1193
# 10    750
# 11    860
# 12    549
# ..    ...
# 693   899
# 696   995
# 697   735
# 700   999
# 702  1020
#
# [315 rows x 1 columns]

# %%
df_dirty_1['monthly_rent'] = df_dirty_1.monthly_rent.str.split('-').str[0].str.replace(',', '').str.extract('(\d+)')
# Out:
# <ipython-input-25-40fbb0f2a17d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_1['monthly_rent'] = df_dirty_1.monthly_rent.str.split('-').str[0].str.replace(',', '').str.extract('(\d+)')

# %%
df_dirty_1
# Out:
#                                                    url listing_id zipcode  \
# 1    https://www.apartments.com/the-marott-apartmen...    cqv6bmf   46208
# 2    https://www.apartments.com/trails-at-lakeside-...    p38me3t   46220
# 10   https://www.apartments.com/waterfront-terrace-...    pr9m19s   46224
# 11   https://www.apartments.com/circle-city-apartme...    xbcddnp   46202
# 12   https://www.apartments.com/cloverleaf-apartmen...    11b7pf4   46241
# ..                                                 ...        ...     ...
# 693  https://www.apartments.com/scandia-apartments-...    9er4df5   46250
# 696  https://www.apartments.com/ayr-indianapolis-in...    fkdb8hv   46220
# 697  https://www.apartments.com/the-avenue-indianap...    z394tby   46202
# 700  https://www.apartments.com/the-lodge-at-trails...    1wp4yw6   46240
# 702  https://www.apartments.com/the-continental-tow...    lskywte   46204
#
#     monthly_rent       bedrooms   bathrooms        square_feet walk_score  \
# 1           1185       1 - 2 bd    1 - 2 ba  609 - 1,092 sq ft         54
# 2           1193       1 - 3 bd    1 - 2 ba  594 - 1,246 sq ft         20
# 10           750       1 - 3 bd    1 - 2 ba  648 - 1,034 sq ft         26
# 11           860  Studio - 2 bd  1 - 2.5 ba  376 - 1,700 sq ft         62
# 12           549       1 - 3 bd  1 - 1.5 ba  586 - 1,240 sq ft         43
# ..           ...            ...         ...                ...        ...
# 693          899       1 - 3 bd  1 - 2.5 ba  780 - 1,759 sq ft         35
# 696          995  Studio - 2 bd    1 - 2 ba  508 - 1,177 sq ft         51
# 697          735  Studio - 4 bd    1 - 4 ba  362 - 1,620 sq ft         64
# 700          999       1 - 2 bd    1 - 2 ba  652 - 1,084 sq ft         32
# 702         1020       1 - 2 bd    1 - 2 ba  550 - 1,100 sq ft         96
#
#     transit_score       deposit  latitude  longitude  pet         neighborhood
# 1              52           NaN    39.805    -86.156  NaN  Mapleton Fall Creek
# 2              12           NaN    39.856    -86.101  NaN         Millersville
# 10             34           NaN    39.818    -86.247  NaN            Eagledale
# 11             57           NaN    39.785    -86.157  NaN       Near Northside
# 12             33           NaN    39.754    -86.261  NaN          Garden City
# ..            ...           ...       ...        ...  ...                  ...
# 693             0           NaN    39.922    -86.071  NaN            Castleton
# 696            33  $250 deposit    39.866    -86.117  NaN             Glendale
# 697            47           NaN    39.781    -86.174  NaN          Circle City
# 700            18           NaN    39.925    -86.138  NaN   Nora Far Northside
# 702            67           NaN    39.773    -86.158  NaN         Indianapolis
#
# [315 rows x 14 columns]

# %%
df_dirty_1['bedrooms'] = df_dirty_1.bedrooms.str.split('-').str[0].str.extract('(\w+)')
# Out:
# <ipython-input-27-33f19a3a653d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_1['bedrooms'] = df_dirty_1.bedrooms.str.split('-').str[0].str.extract('(\w+)')

# %%
df_dirty_1.bedrooms.value_counts()
# Out:
# 1         198
# Studio     94
# 2          23
# Name: bedrooms, dtype: int64

# %%
df_dirty_1.sample(5)
# Out:
#                                                    url listing_id zipcode  \
# 260  https://www.apartments.com/highland-pointe-ind...    g6l4b7y   46228
# 111  https://www.apartments.com/pangea-groves-india...    7n3965x   46205
# 639  https://www.apartments.com/the-legend-at-speed...    h0yhfl2   46224
# 669  https://www.apartments.com/estates-of-creeksid...    jxbt7z5   46227
# 107  https://www.apartments.com/fountain-parc-india...    stmjg25   46220
#
#     monthly_rent bedrooms   bathrooms        square_feet walk_score  \
# 260          735        1    1 - 2 ba  685 - 1,050 sq ft         27
# 111          663   Studio    1 - 2 ba  407 - 1,200 sq ft         67
# 639          892        1        1 ba    571 - 896 sq ft         54
# 669          999        1    1 - 2 ba  675 - 1,175 sq ft         61
# 107         1150        1  1 - 2.5 ba  787 - 1,432 sq ft         39
#
#     transit_score deposit  latitude  longitude  pet           neighborhood
# 260            25     NaN    39.850    -86.194  NaN  Wynnedale Spring Hill
# 111            37     NaN    39.846    -86.138  NaN            Fairgrounds
# 639             0     NaN    39.796    -86.253  NaN               Speedway
# 669            27     NaN    39.649    -86.115  NaN            South Perry
# 107            23     NaN    39.869    -86.087  NaN           Allisonville

# %%
df_dirty_1.bathrooms.str.split('-').str[0].str.extract('(\S+)').astype('float')
# Out:
#         0
# 1   1.000
# 2   1.000
# 10  1.000
# 11  1.000
# 12  1.000
# ..    ...
# 693 1.000
# 696 1.000
# 697 1.000
# 700 1.000
# 702 1.000
#
# [315 rows x 1 columns]

# %%
df_dirty_1.bathrooms.str.split('-').str[0].str.extract('(\S+)').astype('float').value_counts()
# Out:
# 1.000    302
# 1.500      6
# 2.000      3
# 2.500      3
# 0.500      1
# dtype: int64

# %%
df_dirty_1['bathrooms']=df_dirty_1.bathrooms.str.split('-').str[0].str.extract('(\S+)').astype('float')
# Out:
# <ipython-input-32-595cfa017060>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_1['bathrooms']=df_dirty_1.bathrooms.str.split('-').str[0].str.extract('(\S+)').astype('float')

# %%
df_dirty_1.sample(5)
# Out:
#                                                    url listing_id zipcode  \
# 429  https://www.apartments.com/632-mlk-apartments-...    p3mw4rr   46202
# 56   https://www.apartments.com/waterside-at-castle...    c44rsgf   46256
# 122  https://www.apartments.com/townes-at-winthrop-...    gnqxshw   46220
# 193  https://www.apartments.com/lenox-apartments-in...    qkrlqry   46226
# 404  https://www.apartments.com/reflections-apartme...    1t1re46   46260
#
#     monthly_rent bedrooms  bathrooms        square_feet walk_score  \
# 429         1100   Studio      1.000        2,178 sq ft         83
# 56           955        1      1.000    650 - 950 sq ft         35
# 122         2300        2      2.500        1,800 sq ft         88
# 193          850        1      1.000  800 - 1,200 sq ft         13
# 404          889   Studio      1.000  450 - 1,400 sq ft         11
#
#     transit_score deposit  latitude  longitude  pet           neighborhood
# 429            54     NaN    39.776    -86.167  NaN  Downtown Indianapolis
# 56             34     NaN    39.907    -86.040  NaN        I-69 Fall Creek
# 122            38     NaN    39.867    -86.141  NaN           Broad Ripple
# 193             0     NaN    39.852    -86.049  NaN            Brendonwood
# 404            30     NaN    39.900    -86.191  NaN           Indianapolis

# %%
df_dirty_1['square_feet'].str.split('-').str[0].str.replace(',', '').str.extract('(\S+)').astype('float')
# Out:
#           0
# 1   609.000
# 2   594.000
# 10  648.000
# 11  376.000
# 12  586.000
# ..      ...
# 693 780.000
# 696 508.000
# 697 362.000
# 700 652.000
# 702 550.000
#
# [315 rows x 1 columns]

# %%
df_dirty_1['square_feet'] = df_dirty_1['square_feet'].str.split('-').str[0].str.replace(',', '').str.extract('(\S+)').astype('float')
# Out:
# <ipython-input-35-73376ebc8748>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_1['square_feet'] = df_dirty_1['square_feet'].str.split('-').str[0].str.replace(',', '').str.extract('(\S+)').astype('float')

# %%
df_dirty_1.sample()
# Out:
#                                                    url listing_id zipcode  \
# 134  https://www.apartments.com/2936-oxford-ln-indi...    kbyxn58   46218
#
#     monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 134          625        1      1.000      610.000         45            34
#
#     deposit  latitude  longitude  pet           neighborhood
# 134     NaN    39.804    -86.115  NaN  Martindale-Brightwood

# %%
df_dirty_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 315 entries, 1 to 702
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            315 non-null    object
#  1   listing_id     315 non-null    object
#  2   zipcode        315 non-null    object
#  3   monthly_rent   315 non-null    object
#  4   bedrooms       315 non-null    object
#  5   bathrooms      315 non-null    object
#  6   square_feet    314 non-null    object
#  7   walk_score     315 non-null    object
#  8   transit_score  315 non-null    object
#  9   deposit        47 non-null     object
#  10  latitude       315 non-null    float64
#  11  longitude      315 non-null    float64
#  12  pet            9 non-null      float64
#  13  neighborhood   315 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 36.9+ KB

# %%
df_dirty_2['monthly_rent']= df_dirty_2.monthly_rent.str.split("-").str[1].str.replace(',', "").str.extract('(\d+)').astype('float')
# Out:
# <ipython-input-38-41c74efedd24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_2['monthly_rent']= df_dirty_2.monthly_rent.str.split("-").str[1].str.replace(',', "").str.extract('(\d+)').astype('float')

# %%
df_dirty_2.head(2)
# Out:
#                                                  url listing_id zipcode  \
# 1  https://www.apartments.com/the-marott-apartmen...    cqv6bmf   46208
# 2  https://www.apartments.com/trails-at-lakeside-...    p38me3t   46220
#
#    monthly_rent  bedrooms bathrooms        square_feet walk_score  \
# 1      1645.000  1 - 2 bd  1 - 2 ba  609 - 1,092 sq ft         54
# 2      2805.000  1 - 3 bd  1 - 2 ba  594 - 1,246 sq ft         20
#
#   transit_score deposit  latitude  longitude  pet         neighborhood
# 1            52     NaN    39.805    -86.156  NaN  Mapleton Fall Creek
# 2            12     NaN    39.856    -86.101  NaN         Millersville

# %%
df_dirty_2['bedrooms'] = df_dirty_2.bedrooms.str.split("-").str[1].str.extract("(\S+)")
df_dirty_2["bathrooms"] = df_dirty_2.bathrooms.str.split("-").str[1].str.extract("(\S+)").astype("float")
df_dirty_2["square_feet"] = df_dirty_2.square_feet.str.split("-").str[1].str.replace(",","").str.extract("(\S+)").astype("float")
# Out:
# <ipython-input-40-f2d4500fcc95>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_2['bedrooms'] = df_dirty_2.bedrooms.str.split("-").str[1].str.extract("(\S+)")
# <ipython-input-40-f2d4500fcc95>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_2["bathrooms"] = df_dirty_2.bathrooms.str.split("-").str[1].str.extract("(\S+)").astype("float")
# <ipython-input-40-f2d4500fcc95>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_2["square_feet"] = df_dirty_2.square_feet.str.split("-").str[1].str.replace(",","").str.extract("(\S+)").astype("float")

# %%
df_dirty_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 315 entries, 1 to 702
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            315 non-null    object
#  1   listing_id     315 non-null    object
#  2   zipcode        315 non-null    object
#  3   monthly_rent   315 non-null    float64
#  4   bedrooms       294 non-null    object
#  5   bathrooms      259 non-null    float64
#  6   square_feet    300 non-null    float64
#  7   walk_score     315 non-null    object
#  8   transit_score  315 non-null    object
#  9   deposit        47 non-null     object
#  10  latitude       315 non-null    float64
#  11  longitude      315 non-null    float64
#  12  pet            9 non-null      float64
#  13  neighborhood   315 non-null    object
# dtypes: float64(6), object(8)
# memory usage: 36.9+ KB

# %%
df_clean = pd.concat([df_dirty_1, df_dirty_2], axis = 0)

# %%
df_clean.head()
# Out:
#                                                   url listing_id zipcode  \
# 1   https://www.apartments.com/the-marott-apartmen...    cqv6bmf   46208
# 2   https://www.apartments.com/trails-at-lakeside-...    p38me3t   46220
# 10  https://www.apartments.com/waterfront-terrace-...    pr9m19s   46224
# 11  https://www.apartments.com/circle-city-apartme...    xbcddnp   46202
# 12  https://www.apartments.com/cloverleaf-apartmen...    11b7pf4   46241
#
#    monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 1          1185        1      1.000      609.000         54            52
# 2          1193        1      1.000      594.000         20            12
# 10          750        1      1.000      648.000         26            34
# 11          860   Studio      1.000      376.000         62            57
# 12          549        1      1.000      586.000         43            33
#
#    deposit  latitude  longitude  pet         neighborhood
# 1      NaN    39.805    -86.156  NaN  Mapleton Fall Creek
# 2      NaN    39.856    -86.101  NaN         Millersville
# 10     NaN    39.818    -86.247  NaN            Eagledale
# 11     NaN    39.785    -86.157  NaN       Near Northside
# 12     NaN    39.754    -86.261  NaN          Garden City

# %%
df_dirty_3 = df[df.monthly_rent.str.contains('-')!= True]
df_dirty_3
# Out:
#                                                    url listing_id zipcode  \
# 0    https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy   46218
# 3    https://www.apartments.com/7491-n-shadeland-av...    s34dq64   46250
# 4    https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m   46237
# 5    https://www.apartments.com/1102-n-oakland-ave-...    c4kr5zf   46201
# 6    https://www.apartments.com/634-e-10th-st-india...    rl2dfp0   46202
# ..                                                 ...        ...     ...
# 695  https://www.apartments.com/442-parkway-ave-ind...    ek8mt7q   46225
# 698  https://www.apartments.com/1629-hoefgen-street...    hynbrv3   46203
# 699  https://www.apartments.com/550-fletcher-ave-in...    1jk9p55   46203
# 701  https://www.apartments.com/8506-westfield-blvd...    nxzxzyn   46240
# 703  https://www.apartments.com/36-n-ewing-st-india...    zv95hgx   46201
#
#     monthly_rent bedrooms bathrooms  square_feet walk_score transit_score  \
# 0           $751     2 bd      1 ba    679 sq ft         25            33
# 3         $1,795     3 bd      2 ba  2,500 sq ft         54            33
# 4         $1,095     3 bd      1 ba  1,439 sq ft         29            32
# 5         $1,300     3 bd    1.5 ba  1,500 sq ft         67            38
# 6         $1,600     2 bd      2 ba  1,400 sq ft         74            53
# ..           ...      ...       ...          ...        ...           ...
# 695       $2,295     4 bd      3 ba  3,100 sq ft         75            40
# 698       $1,175     3 bd      2 ba  1,000 sq ft         38            37
# 699       $1,249     2 bd    1.5 ba  1,030 sq ft         82            65
# 701       $1,855     1 bd      1 ba    788 sq ft         59            30
# 703       $1,700     2 bd      1 ba  1,600 sq ft         50            40
#
#             deposit  latitude  longitude   pet           neighborhood
# 0      $705 deposit    39.801    -86.126 0.000  Martindale-Brightwood
# 3               NaN    39.890    -86.045   NaN        I-69 Fall Creek
# 4               NaN    39.722    -86.121   NaN     University Heights
# 5      $800 deposit    39.783    -86.113   NaN          Near Eastside
# 6    $1,600 deposit    39.781    -86.146   NaN           Chatham Arch
# ..              ...       ...        ...   ...                    ...
# 695  $2,295 deposit    39.749    -86.150   NaN        Bates-Hendricks
# 698             NaN    39.732    -86.131   NaN         Near Southeast
# 699             NaN    39.761    -86.148   NaN         Fletcher Place
# 701             NaN    39.910    -86.134   NaN          North Central
# 703             NaN    39.770    -86.105   NaN          Near Eastside
#
# [389 rows x 14 columns]

# %%
df_dirty_3['monthly_rent'].str[1:].str.replace(',','')
# Out:
# 0       751
# 3      1795
# 4      1095
# 5      1300
# 6      1600
#        ...
# 695    2295
# 698    1175
# 699    1249
# 701    1855
# 703    1700
# Name: monthly_rent, Length: 389, dtype: object

# %%
df_dirty_3['monthly_rent'] = df_dirty_3['monthly_rent'].str[1:].str.replace(',','')
# Out:
# <ipython-input-46-e881f6b5774b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_3['monthly_rent'] = df_dirty_3['monthly_rent'].str[1:].str.replace(',','')

# %%
df_dirty_3.monthly_rent
# Out:
# 0       751
# 3      1795
# 4      1095
# 5      1300
# 6      1600
#        ...
# 695    2295
# 698    1175
# 699    1249
# 701    1855
# 703    1700
# Name: monthly_rent, Length: 389, dtype: object

# %%
df_dirty_3['bedrooms'] = df_dirty_3['bedrooms'].str.extract("(\S+)")
# Out:
# <ipython-input-48-35ceb5c59e34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_3['bedrooms'] = df_dirty_3['bedrooms'].str.extract("(\S+)")

# %%
df_dirty_3["bathrooms"] = df_dirty_3.bathrooms.str.extract("(\S+)").astype("float")
# Out:
# <ipython-input-49-26803ca0b4a0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_3["bathrooms"] = df_dirty_3.bathrooms.str.extract("(\S+)").astype("float")

# %%
df_dirty_3["square_feet"] = df_dirty_3.square_feet.str.replace(",","").str.extract("(\S+)").astype("float")
# Out:
# <ipython-input-50-3d4475d11906>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dirty_3["square_feet"] = df_dirty_3.square_feet.str.replace(",","").str.extract("(\S+)").astype("float")

# %%
df_dirty_3
# Out:
#                                                    url listing_id zipcode  \
# 0    https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy   46218
# 3    https://www.apartments.com/7491-n-shadeland-av...    s34dq64   46250
# 4    https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m   46237
# 5    https://www.apartments.com/1102-n-oakland-ave-...    c4kr5zf   46201
# 6    https://www.apartments.com/634-e-10th-st-india...    rl2dfp0   46202
# ..                                                 ...        ...     ...
# 695  https://www.apartments.com/442-parkway-ave-ind...    ek8mt7q   46225
# 698  https://www.apartments.com/1629-hoefgen-street...    hynbrv3   46203
# 699  https://www.apartments.com/550-fletcher-ave-in...    1jk9p55   46203
# 701  https://www.apartments.com/8506-westfield-blvd...    nxzxzyn   46240
# 703  https://www.apartments.com/36-n-ewing-st-india...    zv95hgx   46201
#
#     monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 0            751        2      1.000      679.000         25            33
# 3           1795        3      2.000     2500.000         54            33
# 4           1095        3      1.000     1439.000         29            32
# 5           1300        3      1.500     1500.000         67            38
# 6           1600        2      2.000     1400.000         74            53
# ..           ...      ...        ...          ...        ...           ...
# 695         2295        4      3.000     3100.000         75            40
# 698         1175        3      2.000     1000.000         38            37
# 699         1249        2      1.500     1030.000         82            65
# 701         1855        1      1.000      788.000         59            30
# 703         1700        2      1.000     1600.000         50            40
#
#             deposit  latitude  longitude   pet           neighborhood
# 0      $705 deposit    39.801    -86.126 0.000  Martindale-Brightwood
# 3               NaN    39.890    -86.045   NaN        I-69 Fall Creek
# 4               NaN    39.722    -86.121   NaN     University Heights
# 5      $800 deposit    39.783    -86.113   NaN          Near Eastside
# 6    $1,600 deposit    39.781    -86.146   NaN           Chatham Arch
# ..              ...       ...        ...   ...                    ...
# 695  $2,295 deposit    39.749    -86.150   NaN        Bates-Hendricks
# 698             NaN    39.732    -86.131   NaN         Near Southeast
# 699             NaN    39.761    -86.148   NaN         Fletcher Place
# 701             NaN    39.910    -86.134   NaN          North Central
# 703             NaN    39.770    -86.105   NaN          Near Eastside
#
# [389 rows x 14 columns]

# %%
df_final = pd.concat([df_dirty_3, df_clean])

# %%
df_final
# Out:
#                                                    url listing_id zipcode  \
# 0    https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy   46218
# 3    https://www.apartments.com/7491-n-shadeland-av...    s34dq64   46250
# 4    https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m   46237
# 5    https://www.apartments.com/1102-n-oakland-ave-...    c4kr5zf   46201
# 6    https://www.apartments.com/634-e-10th-st-india...    rl2dfp0   46202
# ..                                                 ...        ...     ...
# 693  https://www.apartments.com/scandia-apartments-...    9er4df5   46250
# 696  https://www.apartments.com/ayr-indianapolis-in...    fkdb8hv   46220
# 697  https://www.apartments.com/the-avenue-indianap...    z394tby   46202
# 700  https://www.apartments.com/the-lodge-at-trails...    1wp4yw6   46240
# 702  https://www.apartments.com/the-continental-tow...    lskywte   46204
#
#     monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 0            751        2      1.000      679.000         25            33
# 3           1795        3      2.000     2500.000         54            33
# 4           1095        3      1.000     1439.000         29            32
# 5           1300        3      1.500     1500.000         67            38
# 6           1600        2      2.000     1400.000         74            53
# ..           ...      ...        ...          ...        ...           ...
# 693     1679.000        3      2.500     1759.000         35             0
# 696     1954.000        2      2.000     1177.000         51            33
# 697     3500.000        4      4.000     1620.000         64            47
# 700     1395.000        2      2.000     1084.000         32            18
# 702     1528.000        2      2.000     1100.000         96            67
#
#             deposit  latitude  longitude   pet           neighborhood
# 0      $705 deposit    39.801    -86.126 0.000  Martindale-Brightwood
# 3               NaN    39.890    -86.045   NaN        I-69 Fall Creek
# 4               NaN    39.722    -86.121   NaN     University Heights
# 5      $800 deposit    39.783    -86.113   NaN          Near Eastside
# 6    $1,600 deposit    39.781    -86.146   NaN           Chatham Arch
# ..              ...       ...        ...   ...                    ...
# 693             NaN    39.922    -86.071   NaN              Castleton
# 696    $250 deposit    39.866    -86.117   NaN               Glendale
# 697             NaN    39.781    -86.174   NaN            Circle City
# 700             NaN    39.925    -86.138   NaN     Nora Far Northside
# 702             NaN    39.773    -86.158   NaN           Indianapolis
#
# [1019 rows x 14 columns]

# %%
df_final.monthly_rent.isna().value_counts()
# Out:
# False    995
# True      24
# Name: monthly_rent, dtype: int64

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1019 entries, 0 to 702
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            1019 non-null   object
#  1   listing_id     1008 non-null   object
#  2   zipcode        1008 non-null   object
#  3   monthly_rent   995 non-null    object
#  4   bedrooms       974 non-null    object
#  5   bathrooms      939 non-null    float64
#  6   square_feet    964 non-null    float64
#  7   walk_score     1008 non-null   object
#  8   transit_score  1008 non-null   object
#  9   deposit        209 non-null    object
#  10  latitude       1008 non-null   float64
#  11  longitude      1008 non-null   float64
#  12  pet            45 non-null     float64
#  13  neighborhood   1008 non-null   object
# dtypes: float64(5), object(9)
# memory usage: 119.4+ KB

# %%
df_final.head()
# Out:
#                                                  url listing_id zipcode  \
# 0  https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy   46218
# 3  https://www.apartments.com/7491-n-shadeland-av...    s34dq64   46250
# 4  https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m   46237
# 5  https://www.apartments.com/1102-n-oakland-ave-...    c4kr5zf   46201
# 6  https://www.apartments.com/634-e-10th-st-india...    rl2dfp0   46202
#
#   monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 0          751        2      1.000      679.000         25            33
# 3         1795        3      2.000     2500.000         54            33
# 4         1095        3      1.000     1439.000         29            32
# 5         1300        3      1.500     1500.000         67            38
# 6         1600        2      2.000     1400.000         74            53
#
#           deposit  latitude  longitude   pet           neighborhood
# 0    $705 deposit    39.801    -86.126 0.000  Martindale-Brightwood
# 3             NaN    39.890    -86.045   NaN        I-69 Fall Creek
# 4             NaN    39.722    -86.121   NaN     University Heights
# 5    $800 deposit    39.783    -86.113   NaN          Near Eastside
# 6  $1,600 deposit    39.781    -86.146   NaN           Chatham Arch

# %%
df_final.bedrooms.value_counts()
# Out:
# 3         330
# 1         249
# 2         230
# Studio    103
# 4          56
# 5           6
# Name: bedrooms, dtype: int64

# %%
#Change studio is 0

# %%
df_final.bedrooms.replace('Studio', '0',inplace=True)

# %%
df_final.bedrooms.value_counts()
# Out:
# 3    330
# 1    249
# 2    230
# 0    103
# 4     56
# 5      6
# Name: bedrooms, dtype: int64

# %%
df_final
# Out:
#                                                    url listing_id zipcode  \
# 0    https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy   46218
# 3    https://www.apartments.com/7491-n-shadeland-av...    s34dq64   46250
# 4    https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m   46237
# 5    https://www.apartments.com/1102-n-oakland-ave-...    c4kr5zf   46201
# 6    https://www.apartments.com/634-e-10th-st-india...    rl2dfp0   46202
# ..                                                 ...        ...     ...
# 693  https://www.apartments.com/scandia-apartments-...    9er4df5   46250
# 696  https://www.apartments.com/ayr-indianapolis-in...    fkdb8hv   46220
# 697  https://www.apartments.com/the-avenue-indianap...    z394tby   46202
# 700  https://www.apartments.com/the-lodge-at-trails...    1wp4yw6   46240
# 702  https://www.apartments.com/the-continental-tow...    lskywte   46204
#
#     monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 0            751        2      1.000      679.000         25            33
# 3           1795        3      2.000     2500.000         54            33
# 4           1095        3      1.000     1439.000         29            32
# 5           1300        3      1.500     1500.000         67            38
# 6           1600        2      2.000     1400.000         74            53
# ..           ...      ...        ...          ...        ...           ...
# 693     1679.000        3      2.500     1759.000         35             0
# 696     1954.000        2      2.000     1177.000         51            33
# 697     3500.000        4      4.000     1620.000         64            47
# 700     1395.000        2      2.000     1084.000         32            18
# 702     1528.000        2      2.000     1100.000         96            67
#
#             deposit  latitude  longitude   pet           neighborhood
# 0      $705 deposit    39.801    -86.126 0.000  Martindale-Brightwood
# 3               NaN    39.890    -86.045   NaN        I-69 Fall Creek
# 4               NaN    39.722    -86.121   NaN     University Heights
# 5      $800 deposit    39.783    -86.113   NaN          Near Eastside
# 6    $1,600 deposit    39.781    -86.146   NaN           Chatham Arch
# ..              ...       ...        ...   ...                    ...
# 693             NaN    39.922    -86.071   NaN              Castleton
# 696    $250 deposit    39.866    -86.117   NaN               Glendale
# 697             NaN    39.781    -86.174   NaN            Circle City
# 700             NaN    39.925    -86.138   NaN     Nora Far Northside
# 702             NaN    39.773    -86.158   NaN           Indianapolis
#
# [1019 rows x 14 columns]

# %%
df_final.deposit.value_counts()
# Out:
# $250 deposit      25
# $200 deposit      22
# $500 deposit      15
# $300 deposit      14
# $350 deposit       7
#                   ..
# $1,750 deposit     1
# $850 deposit       1
# $1,350 deposit     1
# $2,085 deposit     1
# $1,998 deposit     1
# Name: deposit, Length: 74, dtype: int64

# %%
df_final.deposit.unique()
# Out:
# array(['$705 deposit', nan, '$800 deposit', '$1,600 deposit',
#        '$825 deposit', '$1,500 deposit', '$1,745 deposit',
#        '$1,900 deposit', '$1,750 deposit', '$1,000 deposit',
#        '$1,200 deposit', '$1,210 deposit', '$3,000 deposit',
#        '$2,085 deposit', '$875 deposit', '$1,100 deposit',
#        '$1,998 deposit', '$750 deposit', '$675 deposit', '$2,450 deposit',
#        '$1,450 deposit', '$950 deposit', '$1,400 deposit', '$795 deposit',
#        '$2,300 deposit', '$1,250 deposit', '$1,800 deposit',
#        '$975 deposit', '$1,010 deposit', '$775 deposit', '$1,300 deposit',
#        '$250 deposit', '$1,110 deposit', '$1,395 deposit', '$895 deposit',
#        '$500 deposit', '$1,350 deposit', '$1,650 deposit',
#        '$1,550 deposit', '$2,800 deposit', '$1,050 deposit',
#        '$2,100 deposit', '$1,700 deposit', '$850 deposit',
#        '$1,795 deposit', '$1,825 deposit', '$700 deposit',
#        '$1,645 deposit', '$200 deposit', '$652 deposit', '$1,670 deposit',
#        '$2,250 deposit', '$1,025 deposit', '$300 deposit',
#        '$1,095 deposit', '$1,420 deposit', '$400 deposit',
#        '$2,400 deposit', '$2,025 deposit', '$655 deposit',
#        '$1,950 deposit', '$2,000 deposit', '$1,495 deposit',
#        '$1,375 deposit', '$2,350 deposit', '$1,920 deposit',
#        '$350 deposit', '$1,575 deposit', '$1,940 deposit', '$575 deposit',
#        '$2,500 deposit', '$2,295 deposit', '$150 deposit', '$100 deposit',
#        '$870 deposit'], dtype=object)

# %%
df_final.deposit.str[1:].str.replace(',','').str.extract('(\d+)')
# Out:
#         0
# 0     705
# 3     NaN
# 4     NaN
# 5     800
# 6    1600
# ..    ...
# 693   NaN
# 696   250
# 697   NaN
# 700   NaN
# 702   NaN
#
# [1019 rows x 1 columns]

# %%
df_final['deposit'] = df_final.deposit.str[1:].str.replace(',','').str.extract('(\d+)')

# %%
df_final
# Out:
#                                                    url listing_id zipcode  \
# 0    https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy   46218
# 3    https://www.apartments.com/7491-n-shadeland-av...    s34dq64   46250
# 4    https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m   46237
# 5    https://www.apartments.com/1102-n-oakland-ave-...    c4kr5zf   46201
# 6    https://www.apartments.com/634-e-10th-st-india...    rl2dfp0   46202
# ..                                                 ...        ...     ...
# 693  https://www.apartments.com/scandia-apartments-...    9er4df5   46250
# 696  https://www.apartments.com/ayr-indianapolis-in...    fkdb8hv   46220
# 697  https://www.apartments.com/the-avenue-indianap...    z394tby   46202
# 700  https://www.apartments.com/the-lodge-at-trails...    1wp4yw6   46240
# 702  https://www.apartments.com/the-continental-tow...    lskywte   46204
#
#     monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 0            751        2      1.000      679.000         25            33
# 3           1795        3      2.000     2500.000         54            33
# 4           1095        3      1.000     1439.000         29            32
# 5           1300        3      1.500     1500.000         67            38
# 6           1600        2      2.000     1400.000         74            53
# ..           ...      ...        ...          ...        ...           ...
# 693     1679.000        3      2.500     1759.000         35             0
# 696     1954.000        2      2.000     1177.000         51            33
# 697     3500.000        4      4.000     1620.000         64            47
# 700     1395.000        2      2.000     1084.000         32            18
# 702     1528.000        2      2.000     1100.000         96            67
#
#     deposit  latitude  longitude   pet           neighborhood
# 0       705    39.801    -86.126 0.000  Martindale-Brightwood
# 3       NaN    39.890    -86.045   NaN        I-69 Fall Creek
# 4       NaN    39.722    -86.121   NaN     University Heights
# 5       800    39.783    -86.113   NaN          Near Eastside
# 6      1600    39.781    -86.146   NaN           Chatham Arch
# ..      ...       ...        ...   ...                    ...
# 693     NaN    39.922    -86.071   NaN              Castleton
# 696     250    39.866    -86.117   NaN               Glendale
# 697     NaN    39.781    -86.174   NaN            Circle City
# 700     NaN    39.925    -86.138   NaN     Nora Far Northside
# 702     NaN    39.773    -86.158   NaN           Indianapolis
#
# [1019 rows x 14 columns]

# %%
df_final.shape
# Out:
# (1019, 14)

# %%
df_final.monthly_rent.notna().value_counts()
# Out:
# True     995
# False     24
# Name: monthly_rent, dtype: int64

# %%
df_final.isnull().sum()
# Out:
# url                0
# listing_id        11
# zipcode           11
# monthly_rent      24
# bedrooms          45
# bathrooms         80
# square_feet       55
# walk_score        11
# transit_score     11
# deposit          810
# latitude          11
# longitude         11
# pet              974
# neighborhood      11
# dtype: int64

# %%
df_final[df_final.monthly_rent.notna() == False]
# Out:
#                                                    url listing_id zipcode  \
# 45   https://www.apartments.com/available-now-india...    erjz33m   46239
# 58   https://www.apartments.com/8149-wood-hollow-ln...        NaN     NaN
# 126  https://www.apartments.com/4529-woodland-ct-in...        NaN     NaN
# 138  https://www.apartments.com/5023-gringo-dr-indi...    ycq31kr   46237
# 154  https://www.apartments.com/6601-black-antler-d...    f1etm6r   46217
# 177  https://www.apartments.com/2620-e-37th-st-indi...    bq9g398   46218
# 220  https://www.apartments.com/2241-brookside-park...    y9xfhgr   46201
# 255  https://www.apartments.com/malls/in/indianapol...        NaN     NaN
# 298  https://www.apartments.com/11926-cardis-court-...    wgt9f0k   46229
# 301  https://www.apartments.com/3652-n-kenwood-ave-...    p61zkbv   46208
# 325  https://www.apartments.com/1909-herford-dr-ind...        NaN     NaN
# 332  https://www.apartments.com/2933-boulevard-pl-i...        NaN     NaN
# 399  https://www.apartments.com/malls/in/indianapol...        NaN     NaN
# 447  https://www.apartments.com/1274-castleford-ln-...        NaN     NaN
# 482  https://www.apartments.com/3651-catalpa-avenue...    7rstblw   46228
# 512  https://www.apartments.com/indianapolis-in/stu...        NaN     NaN
# 532  https://www.apartments.com/3br-house-w-fenced-...    tw1vee8   46205
# 601  https://www.apartments.com/8735-blooming-grove...        NaN     NaN
# 605  https://www.apartments.com/3-br-25-bath-house-...    g7nn2yy   46234
# 636  https://www.apartments.com/1824-brassica-ln-in...    l4vp4we   46217
# 649  https://www.apartments.com/10481-lookout-lane-...    g65lrwx   46234
# 661  https://www.apartments.com/10143-stillwell-dr-...    7s10cdx   46123
# 680  https://www.apartments.com/1739-shawnee-rd-ind...        NaN     NaN
# 692  https://www.apartments.com/malls/in/indianapol...        NaN     NaN
#
#     monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 45           NaN      NaN        NaN          NaN         11             0
# 58           NaN      NaN        NaN          NaN        NaN           NaN
# 126          NaN      NaN        NaN          NaN        NaN           NaN
# 138          NaN      NaN        NaN          NaN         50            27
# 154          NaN      NaN        NaN          NaN          2             0
# 177          NaN      NaN        NaN          NaN         49            41
# 220          NaN      NaN        NaN          NaN         55            39
# 255          NaN      NaN        NaN          NaN        NaN           NaN
# 298          NaN      NaN        NaN          NaN          0             0
# 301          NaN      NaN        NaN          NaN         70            48
# 325          NaN      NaN        NaN          NaN        NaN           NaN
# 332          NaN      NaN        NaN          NaN        NaN           NaN
# 399          NaN      NaN        NaN          NaN        NaN           NaN
# 447          NaN      NaN        NaN          NaN        NaN           NaN
# 482          NaN      NaN        NaN          NaN          7            15
# 512          NaN      NaN        NaN          NaN        NaN           NaN
# 532          NaN      NaN        NaN          NaN         29            31
# 601          NaN      NaN        NaN          NaN        NaN           NaN
# 605          NaN      NaN        NaN          NaN          0             0
# 636          NaN      NaN        NaN          NaN         12             0
# 649          NaN      NaN        NaN          NaN          5             0
# 661          NaN      NaN        NaN          NaN         19             0
# 680          NaN      NaN        NaN          NaN        NaN           NaN
# 692          NaN      NaN        NaN          NaN        NaN           NaN
#
#     deposit  latitude  longitude  pet        neighborhood
# 45      NaN    39.724    -86.032  NaN         Five Points
# 58      NaN       NaN        NaN  NaN                 NaN
# 126     NaN       NaN        NaN  NaN                 NaN
# 138     NaN    39.694    -86.070  NaN       South Emerson
# 154     NaN    39.669    -86.201  NaN      Southern Dunes
# 177     NaN    39.824    -86.118  NaN             Meadows
# 220     NaN    39.787    -86.123  NaN       Near Eastside
# 255     NaN       NaN        NaN  NaN                 NaN
# 298     NaN    39.800    -85.953  NaN         East Warren
# 301     NaN    39.823    -86.161  NaN          Crown Hill
# 325     NaN       NaN        NaN  NaN                 NaN
# 332     NaN       NaN        NaN  NaN                 NaN
# 399     NaN       NaN        NaN  NaN                 NaN
# 447     NaN       NaN        NaN  NaN                 NaN
# 482     NaN    39.861    -86.224  NaN  Snacks Guion Creek
# 512     NaN       NaN        NaN  NaN                 NaN
# 532     NaN    39.839    -86.114  NaN        Millersville
# 601     NaN       NaN        NaN  NaN                 NaN
# 605     NaN    39.800    -86.338  NaN        Indianapolis
# 636     NaN    39.670    -86.192  NaN        Dakota Ridge
# 649     NaN    39.799    -86.337  NaN        Indianapolis
# 661     NaN    39.773    -86.344  NaN                Avon
# 680     NaN       NaN        NaN  NaN                 NaN
# 692     NaN       NaN        NaN  NaN                 NaN

# %%
df_final.dropna(subset=['monthly_rent'],inplace=True)

# %%
df_final
# Out:
#                                                    url listing_id zipcode  \
# 0    https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy   46218
# 3    https://www.apartments.com/7491-n-shadeland-av...    s34dq64   46250
# 4    https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m   46237
# 5    https://www.apartments.com/1102-n-oakland-ave-...    c4kr5zf   46201
# 6    https://www.apartments.com/634-e-10th-st-india...    rl2dfp0   46202
# ..                                                 ...        ...     ...
# 693  https://www.apartments.com/scandia-apartments-...    9er4df5   46250
# 696  https://www.apartments.com/ayr-indianapolis-in...    fkdb8hv   46220
# 697  https://www.apartments.com/the-avenue-indianap...    z394tby   46202
# 700  https://www.apartments.com/the-lodge-at-trails...    1wp4yw6   46240
# 702  https://www.apartments.com/the-continental-tow...    lskywte   46204
#
#     monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 0            751        2      1.000      679.000         25            33
# 3           1795        3      2.000     2500.000         54            33
# 4           1095        3      1.000     1439.000         29            32
# 5           1300        3      1.500     1500.000         67            38
# 6           1600        2      2.000     1400.000         74            53
# ..           ...      ...        ...          ...        ...           ...
# 693     1679.000        3      2.500     1759.000         35             0
# 696     1954.000        2      2.000     1177.000         51            33
# 697     3500.000        4      4.000     1620.000         64            47
# 700     1395.000        2      2.000     1084.000         32            18
# 702     1528.000        2      2.000     1100.000         96            67
#
#     deposit  latitude  longitude   pet           neighborhood
# 0       705    39.801    -86.126 0.000  Martindale-Brightwood
# 3       NaN    39.890    -86.045   NaN        I-69 Fall Creek
# 4       NaN    39.722    -86.121   NaN     University Heights
# 5       800    39.783    -86.113   NaN          Near Eastside
# 6      1600    39.781    -86.146   NaN           Chatham Arch
# ..      ...       ...        ...   ...                    ...
# 693     NaN    39.922    -86.071   NaN              Castleton
# 696     250    39.866    -86.117   NaN               Glendale
# 697     NaN    39.781    -86.174   NaN            Circle City
# 700     NaN    39.925    -86.138   NaN     Nora Far Northside
# 702     NaN    39.773    -86.158   NaN           Indianapolis
#
# [995 rows x 14 columns]

# %%
df_final.isnull().sum()
# Out:
# url                0
# listing_id         0
# zipcode            0
# monthly_rent       0
# bedrooms          21
# bathrooms         56
# square_feet       31
# walk_score         0
# transit_score      0
# deposit          786
# latitude           0
# longitude          0
# pet              950
# neighborhood       0
# dtype: int64

# %%
df_final.bedrooms.notna().value_counts()
# Out:
# True     974
# False     21
# Name: bedrooms, dtype: int64

# %%
df_final[df_final.bedrooms.notna() != True]
# Out:
#                                                    url listing_id zipcode  \
# 122  https://www.apartments.com/townes-at-winthrop-...    gnqxshw   46220
# 123  https://www.apartments.com/beech-tree-glen-apa...    p31f0ct   46107
# 134  https://www.apartments.com/2936-oxford-ln-indi...    kbyxn58   46218
# 179  https://www.apartments.com/devonshire-apartmen...    7mw91dx   46204
# 188  https://www.apartments.com/5117-e-38th-st-indi...    r4fbfz3   46218
# 219  https://www.apartments.com/indy-town-apartment...    grrfwsx   46219
# 286  https://www.apartments.com/dawson-village-indi...    wdg6h2j   46203
# 304  https://www.apartments.com/ashgrove-apartments...    f3txf4s   46241
# 318  https://www.apartments.com/cumberland-manor-in...    tge35j9   46229
# 405  https://www.apartments.com/ivy-knoll-indianapo...    7eltl3z   46250
# 414  https://www.apartments.com/ritchey-reserve-fis...    w3pdtel   46038
# 429  https://www.apartments.com/632-mlk-apartments-...    p3mw4rr   46202
# 499  https://www.apartments.com/pangea-vistas-india...    412mcmh   46219
# 506  https://www.apartments.com/the-delaware-apartm...    cthvegf   46205
# 542  https://www.apartments.com/saxony-court-indian...    gelksqz   46219
# 576  https://www.apartments.com/townhomes-at-fall-c...    qs8znhy   46205
# 604  https://www.apartments.com/wheeler-lofts-india...    wf2nmdk   46203
# 610  https://www.apartments.com/the-ripple-indianap...    46bl3ml   46220
# 622  https://www.apartments.com/broad-ripple-apartm...    9b499y4   46220
# 638  https://www.apartments.com/schoolhouse-flats-i...    570n2zm   46219
# 650  https://www.apartments.com/redwood-indianapoli...    08xl6e3   46237
#
#     monthly_rent bedrooms  bathrooms  square_feet walk_score transit_score  \
# 122     2500.000      NaN        NaN          NaN         88            38
# 123     1068.000      NaN        NaN          NaN         48             0
# 134      675.000      NaN        NaN          NaN         45            34
# 179      645.000      NaN        NaN      450.000         99            67
# 188     1200.000      NaN        NaN          NaN         53            38
# 219     3566.000      NaN        NaN     1340.000         38            37
# 286      715.000      NaN        NaN      900.000         26            34
# 304      875.000      NaN        NaN          NaN         44            30
# 318     1389.000      NaN        NaN     1184.000         42             0
# 405     1159.000      NaN        NaN          NaN         48            32
# 414     1449.000      NaN        NaN          NaN         14             0
# 429     3000.000      NaN        NaN          NaN         83            54
# 499     1411.000      NaN      1.500      910.000         47            38
# 506     1900.000      NaN        NaN          NaN         69            52
# 542      795.000      NaN        NaN          NaN         72            37
# 576     1859.000      NaN      2.500     1385.000         66            52
# 604     1709.000      NaN        NaN          NaN         87            40
# 610     2184.000      NaN      2.000     1189.000         76            36
# 622     1475.000      NaN      1.500     1000.000         90            38
# 638     1049.000      NaN        NaN          NaN         43            26
# 650     3122.000      NaN        NaN     1709.000         17            19
#
#     deposit  latitude  longitude   pet           neighborhood
# 122     NaN    39.867    -86.141   NaN           Broad Ripple
# 123     NaN    39.709    -86.084   NaN            Beech Grove
# 134     NaN    39.804    -86.115   NaN  Martindale-Brightwood
# 179     NaN    39.773    -86.153   NaN           Chatham Arch
# 188     100    39.825    -86.083 0.000        Arlington Woods
# 219     870    39.797    -86.062   NaN               Eastside
# 286     200    39.732    -86.128   NaN         Near Southeast
# 304     NaN    39.749    -86.281   NaN  Chapel Hill Ben Davis
# 318     NaN    39.781    -85.956   NaN             Cumberland
# 405     NaN    39.904    -86.070 0.000              Castleton
# 414     250    39.941    -86.030   NaN                Fishers
# 429     NaN    39.776    -86.167   NaN  Downtown Indianapolis
# 499     NaN    39.787    -86.065   NaN               Eastside
# 506     NaN    39.798    -86.153   NaN       Fall Creek Place
# 542     300    39.770    -86.069   NaN              Irvington
# 576     200    39.801    -86.152   NaN       Fall Creek Place
# 604     NaN    39.750    -86.141   NaN        Fountain Square
# 610     NaN    39.869    -86.134   NaN           Indianapolis
# 622     250    39.868    -86.140   NaN           Broad Ripple
# 638     NaN    39.765    -86.065   NaN              Irvington
# 650     500    39.653    -86.070   NaN         South Franklin

# %%
df_final.isnull().sum()/df_final.shape[0] * 100
# Out:
# url              0.000
# listing_id       0.000
# zipcode          0.000
# monthly_rent     0.000
# bedrooms         2.111
# bathrooms        5.628
# square_feet      3.116
# walk_score       0.000
# transit_score    0.000
# deposit         78.995
# latitude         0.000
# longitude        0.000
# pet             95.477
# neighborhood     0.000
# dtype: float64

# %%
df_final.dropna(subset=['bedrooms'],inplace=True)

# %%
df_final.isnull().sum()
# Out:
# url                0
# listing_id         0
# zipcode            0
# monthly_rent       0
# bedrooms           0
# bathrooms         39
# square_feet       19
# walk_score         0
# transit_score      0
# deposit          773
# latitude           0
# longitude          0
# pet              931
# neighborhood       0
# dtype: int64

# %%
df_final.zipcode = df_final.zipcode.astype('int')

# %%
df_final.bedrooms = df_final.bedrooms.astype('int')

# %%
df_final.monthly_rent.unique()
# Out:
# array(['751', '1795', '1095', '1300', '1600', '650', '825', '1790',
#        '2500', '1675', '1550', '1495', '929', '1575', '1695', '1745',
#        '1557', '1809', '1705', '1580', '1670', '900', '1825', '1125',
#        '1900', '1750', '1000', '2010', '1595', '1200', '1830', '1210',
#        '3000', '2085', '2395', '875', '995', '1100', '1998', '1660',
#        '1295', '750', '675', '2200', '1850', '2450', '1920', '1450',
#        '950', '629', '1400', '1115', '800', '1635', '1425', '1720',
#        '1445', '1985', '795', '2300', '1800', '1395', '884', '1415',
#        '1995', '1250', '1500', '850', '1040', '1150', '1810', '1860',
#        '1010', '775', '1775', '3850', '1650', '3472', '1725', '1350',
#        '1110', '1195', '1685', '895', '550', '925', '2195', '1610',
#        '1717', '625', '1570', '500', '2800', '685', '2430', '1515',
#        '1050', '2100', '2486', '1890', '2095', '1700', '1805', '1545',
#        '1640', '2015', '1525', '998', '700', '1645', '640', '2495',
#        '1230', '999', '1420', '1780', '749', '778', '2250', '1025',
#        '1075', '879', '1845', '1604', '965', '2050', '1733', '2353',
#        '975', '1275', '1475', '1235', '1630', '1034', '2045', '2105',
#        '1665', '1330', '2529', '1740', '1945', '1955', '1135', '1801',
#        '1765', '2025', '1634', '599', '1039', '1625', '1520', '2065',
#        '2193', '2046', 'all for Rent', '1590', '655', '1950', '725',
#        '1325', '1375', '1875', '849', '1164', '2334', '2350', '1749',
#        '1925', '2400', '1456', '1614', '600', '1940', '2192', '1171',
#        '575', '620', '2418', '2295', '1175', '1249', '1855', '1185',
#        '1193', '860', '549', '931', '855', '579', '805', '1309', '799',
#        '745', '899', '905', '1864', '1090', '871', '1128', '955', '609',
#        '1082', '1069', '1599', '2062', '779', '985', '814', '852', '865',
#        '663', '961', '720', '699', '987', '1008', '1019', '1045', '2289',
#        '573', '765', '1215', '660', '755', '693', '854', '935', '1299',
#        '624', '830', '810', '1048', '1239', '602', '710', '450', '552',
#        '990', '1015', '744', '1223', '587', '869', '858', '722', '1085',
#        '665', '956', '1081', '735', '1218', '759', '910', '1277', '645',
#        '785', '703', '615', '649', '1399', '1174', '605', '769', '1079',
#        '2600', '626', '1225', '1244', '1065', '1117', '894', '815',
#        '1151', '986', '959', '1042', '934', '1060', '1220', '530', '686',
#        '1029', '1770', '1165', '970', '1404', '920', '1433', '827', '834',
#        '889', '1139', '909', '964', '1360', '690', '903', '1565', '1134',
#        '1499', '1268', '1149', '811', '1037', '840', '822', '1099', '646',
#        '1049', '618', '589', '945', '770', '1377', '1326', '831', '936',
#        '1378', '1155', '1319', '659', '870', '1289', '731', '558', '1472',
#        '1087', '1146', '912', '1449', '1130', '911', '1303', '545', '797',
#        '927', '1094', '571', '1421', '1009', '1129', '569', '740', '1286',
#        '630', '791', '723', '940', '969', '892', '932', '681', '1507',
#        '635', '613', '1365', '715', '1144', '610', '1063', '662', '1020',
#        1645.0, 2805.0, 1070.0, 2043.0, 860.0, 1420.0, 1567.0, 739.0,
#        1575.0, 1210.0, 3148.0, 929.0, 1250.0, 1125.0, 1200.0, 2975.0,
#        2045.0, 1940.0, 1574.0, 2075.0, 1400.0, 1900.0, 1205.0, 1435.0,
#        2009.0, 1080.0, 729.0, 1348.0, 1075.0, 1539.0, 3639.0, 2949.0,
#        5228.0, 1240.0, 1184.0, 940.0, 1775.0, 1009.0, 2135.0, 1830.0,
#        1455.0, 989.0, 1025.0, 1212.0, 1224.0, 1620.0, 1375.0, 1202.0,
#        1479.0, 1130.0, 1004.0, 1359.0, 1549.0, 2169.0, 3224.0, 890.0,
#        1707.0, 2265.0, 1054.0, 891.0, 1160.0, 1875.0, 2014.0, 2160.0,
#        2340.0, 834.0, 993.0, 914.0, 1255.0, 1460.0, 1470.0, 3399.0,
#        2004.0, 982.0, 1300.0, 1275.0, 750.0, 1021.0, 1490.0, 1079.0,
#        1570.0, 1500.0, 1922.0, 1750.0, 1299.0, 1096.0, 1522.0, 1034.0,
#        1040.0, 1015.0, 1350.0, 1005.0, 1323.0, 2013.0, 846.0, 2068.0,
#        1584.0, 1045.0, 5478.0, 865.0, 1324.0, 3805.0, 1243.0, 1055.0,
#        1964.0, 1114.0, 1727.0, 1170.0, 1467.0, 922.0, 1759.0, 1105.0,
#        3300.0, 1189.0, 2425.0, 1711.0, 2100.0, 1458.0, 1469.0, 2110.0,
#        1108.0, 2599.0, 1582.0, 2142.0, 925.0, 1099.0, 1640.0, 2385.0,
#        907.0, 1340.0, 1450.0, 1150.0, 1700.0, 1229.0, 1521.0, 6089.0,
#        1390.0, 1560.0, 1768.0, 870.0, 1405.0, 800.0, 1869.0, 1612.0,
#        2105.0, 3880.0, 1708.0, 1709.0, 1295.0, 1649.0, 640.0, 1239.0,
#        2006.0, 2690.0, 2134.0, 2199.0, 1675.0, 850.0, 2230.0, 1855.0,
#        2401.0, 1100.0, 6465.0, 2318.0, 1369.0, 5154.0, 1994.0, 740.0,
#        3149.0, 775.0, 892.0, 1851.0, 1315.0, 810.0, 1270.0, 1095.0,
#        2305.0, 3231.0, 2102.0, 1550.0, 1859.0, 1498.0, 1465.0, 1249.0,
#        1805.0, 1010.0, 6472.0, 899.0, 1718.0, 1510.0, 1334.0, 1520.0,
#        2640.0, 1911.0, 1048.0, 13124.0, 1935.0, 795.0, 1955.0, 1525.0,
#        1845.0, 2129.0, 4627.0, 1121.0, 1425.0, 1209.0, 3139.0, 900.0,
#        1468.0, 3623.0, 1140.0, 1568.0, 1833.0, 1145.0, 1385.0, 4043.0,
#        1426.0, 1113.0, 1335.0, 1344.0, 1171.0, 1148.0, 1379.0, 3001.0,
#        1695.0, 2971.0, 905.0, 1044.0, 1410.0, 3385.0, 2568.0, 3600.0,
#        970.0, 4390.0, 2585.0, 2970.0, 984.0, 1494.0, 1265.0, 1696.0,
#        1535.0, 1120.0, 1088.0, 1679.0, 1954.0, 3500.0, 1395.0, 1528.0],
#       dtype=object)

# %%
df_final.drop(df_final.index[df_final['monthly_rent'] =='all for Rent'], inplace=True)

# %%
df_final['monthly_rent'] = df_final['monthly_rent'].astype('int')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 973 entries, 0 to 702
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            973 non-null    object
#  1   listing_id     973 non-null    object
#  2   zipcode        973 non-null    int64
#  3   monthly_rent   973 non-null    int64
#  4   bedrooms       973 non-null    int64
#  5   bathrooms      934 non-null    float64
#  6   square_feet    954 non-null    float64
#  7   walk_score     973 non-null    object
#  8   transit_score  973 non-null    object
#  9   deposit        201 non-null    object
#  10  latitude       973 non-null    float64
#  11  longitude      973 non-null    float64
#  12  pet            43 non-null     float64
#  13  neighborhood   973 non-null    object
# dtypes: float64(5), int64(3), object(6)
# memory usage: 114.0+ KB

# %%
df_final[df_final.bathrooms.notna() != True]
# Out:
#                                                    url listing_id  zipcode  \
# 25   https://www.apartments.com/sawmill-apartments-...    peg11lr    46237
# 67   https://www.apartments.com/maple-court-indiana...    mkh7pxk    46205
# 73   https://www.apartments.com/five-twenty-virgini...    tf7y05c    46203
# 118  https://www.apartments.com/english-village-ind...    n1mpqgq    46239
# 173  https://www.apartments.com/senate-manor-indian...    t6e6cb9    46204
# 195  https://www.apartments.com/suites-of-irvington...    7tlqqyy    46219
# 200  https://www.apartments.com/forte-indianapolis-...    rj1vxq0    46203
# 233  https://www.apartments.com/aspen-pointe-apartm...    f70mgxs    46221
# 238  https://www.apartments.com/the-retreat-on-wash...    ys1r1lr    46222
# 244  https://www.apartments.com/parc-bordeaux-apart...    dhmbxyh    46227
# 245  https://www.apartments.com/historic-marcy-vill...    jxccjs4    46205
# 257  https://www.apartments.com/northwoods-apartmen...    3cnsc5d    46234
# 273  https://www.apartments.com/wellington-square-a...    34js65e    46220
# 274  https://www.apartments.com/madison-lofts-india...    zpq104w    46225
# 284  https://www.apartments.com/butler-place-indian...    nhs553q    46219
# 297  https://www.apartments.com/indy-flats-indianap...    5l46s5q    46202
# 309  https://www.apartments.com/pinnacle-on-meridia...    qsfny6w    46260
# 319  https://www.apartments.com/the-win-townhomes-i...    dw9rvnh    46220
# 339  https://www.apartments.com/apartments-marten-c...    xgz8q4q    46226
# 347  https://www.apartments.com/pangea-courts-india...    dn9c6vk    46201
# 361  https://www.apartments.com/penn-street-tower-i...    kegegfc    46204
# 362  https://www.apartments.com/stonehedge-apartmen...    t8hfdv9    46142
# 363  https://www.apartments.com/river-west-flats-in...    pn09lqt    46222
# 377  https://www.apartments.com/village-at-fall-cre...    l9derhg    46205
# 415  https://www.apartments.com/the-courts-of-monon...    vg4ckge    46205
# 440  https://www.apartments.com/dunbar-court-indian...    ec0t2cq    46202
# 471  https://www.apartments.com/ninth-avenue-apartm...    tp8pveb    46237
# 480  https://www.apartments.com/coventry-park-villa...    h7wlcb2    46237
# 485  https://www.apartments.com/churchman-woods-ind...    zvv30pw    46203
# 488  https://www.apartments.com/turtle-creek-indian...    fsy27ds    46260
# 495  https://www.apartments.com/country-club-apartm...    syzgy54    46227
# 562  https://www.apartments.com/st-agnes-indianapol...    6pz8wtt    46202
# 575  https://www.apartments.com/the-towers-at-crook...    dedm88k    46268
# 583  https://www.apartments.com/the-sheldrake-apart...    gcybyew    46208
# 595  https://www.apartments.com/pangea-vineyards-in...    hsgrr03    46235
# 606  https://www.apartments.com/spicewood-indianapo...    cfbjm7e    46227
# 639  https://www.apartments.com/the-legend-at-speed...    h0yhfl2    46224
# 645  https://www.apartments.com/512-e-minnesota-st-...    pe2bf9r    46203
# 651  https://www.apartments.com/briergate-indianapo...    s460sx4    46229
#
#      monthly_rent  bedrooms  bathrooms  square_feet walk_score transit_score  \
# 25            929         2        NaN      950.000          2            23
# 67            729         2        NaN      750.000         60            50
# 73           1539         2        NaN     1044.000         80            60
# 118          1004         2        NaN      770.000         15            21
# 173           914         1        NaN      666.000         90            63
# 195           750         2        NaN      700.000         76            37
# 200          1490         1        NaN      743.000         87            40
# 233          1184         2        NaN      814.000         29            22
# 238          1034         2        NaN      955.000         43            37
# 244          1015         2        NaN     1051.000         24            20
# 245          1350         2        NaN      915.000         51            36
# 257           846         2        NaN      800.000         31            30
# 273           865         2        NaN      870.000         87            39
# 274          1324         2        NaN      929.000         50            35
# 284           750         1        NaN      652.000         73            38
# 297           922         1        NaN      569.000         75            57
# 309          3300         3        NaN          NaN         22            28
# 319          2100         3        NaN     1333.000         91            38
# 339           925         2        NaN      980.000         54             0
# 347           907         2        NaN      780.000         64             0
# 361          1700         2        NaN     1023.000         99            68
# 362          1229         2        NaN     1014.000         38             0
# 363          1521         2        NaN      880.000         17            40
# 377           800         1        NaN      635.000         38            46
# 415           640         1        NaN      593.000         38            46
# 440           850         1        NaN      770.000         75            52
# 471          1369         3        NaN     1105.000         15             0
# 480          1675         3        NaN     1690.000         19            30
# 485           740         2        NaN      725.000         30             0
# 488           892         2        NaN      900.000         24            34
# 495           810         2        NaN      621.000         58            34
# 562           795         1        NaN      750.000         60            56
# 575          1121         2        NaN      828.000         58            28
# 583           900         2        NaN      830.000         68            52
# 595          1200         2        NaN      840.000         39            35
# 606           900         3        NaN     1152.000         49            34
# 639          1171         2        NaN      896.000         54             0
# 645          1125         2        NaN      905.000         63            39
# 651           905         2        NaN      852.000         23            30
#
#     deposit  latitude  longitude   pet                neighborhood
# 25      NaN    39.702    -86.105   NaN               South Emerson
# 67      NaN    39.820    -86.155   NaN         Mapleton Fall Creek
# 73      NaN    39.759    -86.147   NaN              Fletcher Place
# 118     NaN    39.759    -86.035   NaN                   East Gate
# 173     NaN    39.775    -86.163   NaN                 Circle City
# 195     NaN    39.771    -86.069   NaN                   Irvington
# 200     NaN    39.750    -86.140   NaN       Downtown Indianapolis
# 233     NaN    39.696    -86.263   NaN                Valley Mills
# 238     NaN    39.769    -86.209 0.000                   Hawthorne
# 244     NaN    39.695    -86.109   NaN                    Edgewood
# 245     NaN    39.840    -86.134   NaN                Indianapolis
# 257     NaN    39.776    -86.324   NaN       Chapel Hill Ben Davis
# 273     NaN    39.872    -86.146   NaN                Broad Ripple
# 274     NaN    39.748    -86.155   NaN              Near Southside
# 284     NaN    39.771    -86.079   NaN                   Irvington
# 297     NaN    39.785    -86.154   NaN              Near Northside
# 309     250    39.912    -86.159   NaN              Meridian Hills
# 319     NaN    39.868    -86.142   NaN                Broad Ripple
# 339     675    39.834    -86.030   NaN                Far Eastside
# 347     NaN    39.778    -86.095   NaN               Near Eastside
# 361     NaN    39.769    -86.156   NaN                 Circle City
# 362     NaN    39.633    -86.152   NaN      Southside Indianapolis
# 363     NaN    39.783    -86.191   NaN  Near Westside Indianapolis
# 377     NaN    39.822    -86.137   NaN         Mapleton Fall Creek
# 415     NaN    39.823    -86.137   NaN         Mapleton Fall Creek
# 440     NaN    39.782    -86.169   NaN       Downtown Indianapolis
# 471     NaN    39.700    -86.095   NaN               South Emerson
# 480     NaN    39.687    -86.085   NaN               South Emerson
# 485     NaN    39.715    -86.076   NaN                Indianapolis
# 488     NaN    39.906    -86.192   NaN       St Vincent Greenbriar
# 495     NaN    39.721    -86.153   NaN                 North Perry
# 562     NaN    39.785    -86.158   NaN              Near Northside
# 575     NaN    39.899    -86.218   NaN                     Augusta
# 583     NaN    39.799    -86.157   NaN              Near Northside
# 595     NaN    39.831    -85.990   NaN                Far Eastside
# 606     NaN    39.712    -86.152   NaN                 North Perry
# 639     NaN    39.796    -86.253   NaN                    Speedway
# 645     NaN    39.745    -86.149   NaN             Bates-Hendricks
# 651     250    39.809    -86.007   NaN                Far Eastside

# %%
df_final.describe()
# Out:
#         zipcode  monthly_rent  bedrooms  bathrooms  square_feet  latitude  \
# count   973.000       973.000   973.000    934.000      954.000   973.000
# mean  46221.542      1394.843     2.006      1.574     1128.635    39.793
# std      30.445       776.235     1.142      0.617      623.972     0.077
# min   46038.000       450.000     0.000      0.500       50.000    39.627
# 25%   46205.000       929.000     1.000      1.000      699.250    39.756
# 50%   46222.000      1250.000     2.000      1.500     1027.500    39.792
# 75%   46237.000      1685.000     3.000      2.000     1400.000    39.850
# max   46298.000     13124.000     5.000      4.000     9991.000    39.946
#
#        longitude    pet
# count    973.000 43.000
# mean     -86.148  0.000
# std        0.088  0.000
# min      -86.341  0.000
# 25%      -86.204  0.000
# 50%      -86.146  0.000
# 75%      -86.092  0.000
# max      -85.950  0.000

# %%
df_final[df_final.bathrooms.notna() != True].mean()
# Out:
# zipcode                                                  46218.769
# monthly_rent                                              1133.846
# bedrooms                                                     1.923
# bathrooms                                                      NaN
# square_feet                                                875.789
# walk_score      66872202761212674611553154858177417713736846016...
# transit_score   60271850342923658272017681227559594515120613133...
# latitude                                                    39.779
# longitude                                                  -86.139
# pet                                                          0.000
# dtype: float64

# %%
df_final[df_final.bathrooms.notna() == True].mean()
# Out:
# zipcode        46221.657
# monthly_rent    1405.741
# bedrooms           2.010
# bathrooms          1.574
# square_feet     1139.124
# latitude          39.793
# longitude        -86.148
# pet                0.000
# dtype: float64

# %%
df_final[df_final.bathrooms.notna() != True].bathrooms
# Out:
# 25    NaN
# 67    NaN
# 73    NaN
# 118   NaN
# 173   NaN
# 195   NaN
# 200   NaN
# 233   NaN
# 238   NaN
# 244   NaN
# 245   NaN
# 257   NaN
# 273   NaN
# 274   NaN
# 284   NaN
# 297   NaN
# 309   NaN
# 319   NaN
# 339   NaN
# 347   NaN
# 361   NaN
# 362   NaN
# 363   NaN
# 377   NaN
# 415   NaN
# 440   NaN
# 471   NaN
# 480   NaN
# 485   NaN
# 488   NaN
# 495   NaN
# 562   NaN
# 575   NaN
# 583   NaN
# 595   NaN
# 606   NaN
# 639   NaN
# 645   NaN
# 651   NaN
# Name: bathrooms, dtype: float64

# %%
df_final[df_final.bathrooms.notna() != True].bathrooms.astype('str').str.replace('nan', '1.5')
# Out:
# 25     1.5
# 67     1.5
# 73     1.5
# 118    1.5
# 173    1.5
# 195    1.5
# 200    1.5
# 233    1.5
# 238    1.5
# 244    1.5
# 245    1.5
# 257    1.5
# 273    1.5
# 274    1.5
# 284    1.5
# 297    1.5
# 309    1.5
# 319    1.5
# 339    1.5
# 347    1.5
# 361    1.5
# 362    1.5
# 363    1.5
# 377    1.5
# 415    1.5
# 440    1.5
# 471    1.5
# 480    1.5
# 485    1.5
# 488    1.5
# 495    1.5
# 562    1.5
# 575    1.5
# 583    1.5
# 595    1.5
# 606    1.5
# 639    1.5
# 645    1.5
# 651    1.5
# Name: bathrooms, dtype: object

# %%
df_final['bathrooms'] = df_final['bathrooms'].fillna(1.5)

# %%
df_final.isnull().sum()
# Out:
# url                0
# listing_id         0
# zipcode            0
# monthly_rent       0
# bedrooms           0
# bathrooms          0
# square_feet       19
# walk_score         0
# transit_score      0
# deposit          772
# latitude           0
# longitude          0
# pet              930
# neighborhood       0
# dtype: int64

# %%
df_final['deposit'] = df_final['deposit'].fillna(df_final['monthly_rent'])

# %%
df_final
# Out:
#                                                    url listing_id  zipcode  \
# 0    https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy    46218
# 3    https://www.apartments.com/7491-n-shadeland-av...    s34dq64    46250
# 4    https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m    46237
# 5    https://www.apartments.com/1102-n-oakland-ave-...    c4kr5zf    46201
# 6    https://www.apartments.com/634-e-10th-st-india...    rl2dfp0    46202
# ..                                                 ...        ...      ...
# 693  https://www.apartments.com/scandia-apartments-...    9er4df5    46250
# 696  https://www.apartments.com/ayr-indianapolis-in...    fkdb8hv    46220
# 697  https://www.apartments.com/the-avenue-indianap...    z394tby    46202
# 700  https://www.apartments.com/the-lodge-at-trails...    1wp4yw6    46240
# 702  https://www.apartments.com/the-continental-tow...    lskywte    46204
#
#      monthly_rent  bedrooms  bathrooms  square_feet walk_score transit_score  \
# 0             751         2      1.000      679.000         25            33
# 3            1795         3      2.000     2500.000         54            33
# 4            1095         3      1.000     1439.000         29            32
# 5            1300         3      1.500     1500.000         67            38
# 6            1600         2      2.000     1400.000         74            53
# ..            ...       ...        ...          ...        ...           ...
# 693          1679         3      2.500     1759.000         35             0
# 696          1954         2      2.000     1177.000         51            33
# 697          3500         4      4.000     1620.000         64            47
# 700          1395         2      2.000     1084.000         32            18
# 702          1528         2      2.000     1100.000         96            67
#
#     deposit  latitude  longitude   pet           neighborhood
# 0       705    39.801    -86.126 0.000  Martindale-Brightwood
# 3      1795    39.890    -86.045   NaN        I-69 Fall Creek
# 4      1095    39.722    -86.121   NaN     University Heights
# 5       800    39.783    -86.113   NaN          Near Eastside
# 6      1600    39.781    -86.146   NaN           Chatham Arch
# ..      ...       ...        ...   ...                    ...
# 693    1679    39.922    -86.071   NaN              Castleton
# 696     250    39.866    -86.117   NaN               Glendale
# 697    3500    39.781    -86.174   NaN            Circle City
# 700    1395    39.925    -86.138   NaN     Nora Far Northside
# 702    1528    39.773    -86.158   NaN           Indianapolis
#
# [973 rows x 14 columns]

# %%
df_final['deposit'] = df_final['deposit'].astype('int')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 973 entries, 0 to 702
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            973 non-null    object
#  1   listing_id     973 non-null    object
#  2   zipcode        973 non-null    int64
#  3   monthly_rent   973 non-null    int64
#  4   bedrooms       973 non-null    int64
#  5   bathrooms      973 non-null    float64
#  6   square_feet    954 non-null    float64
#  7   walk_score     973 non-null    object
#  8   transit_score  973 non-null    object
#  9   deposit        973 non-null    int64
#  10  latitude       973 non-null    float64
#  11  longitude      973 non-null    float64
#  12  pet            43 non-null     float64
#  13  neighborhood   973 non-null    object
# dtypes: float64(5), int64(4), object(5)
# memory usage: 114.0+ KB

# %%
df_final.columns
# Out:
# Index(['url', 'listing_id', 'zipcode', 'monthly_rent', 'bedrooms', 'bathrooms',
#        'square_feet', 'walk_score', 'transit_score', 'deposit', 'latitude',
#        'longitude', 'pet', 'neighborhood'],
#       dtype='object')

# %%
df_final.neighborhood.value_counts()
# Out:
# Indianapolis         85
# Circle City          40
# Near Eastside        33
# Far Eastside         31
# South Perry          30
#                      ..
# 16 Tech               1
# West Indianapolis     1
# Southeast Warren      1
# Ravenswood            1
# West Newton           1
# Name: neighborhood, Length: 104, dtype: int64

# %%
df_final.head()
# Out:
#                                                  url listing_id  zipcode  \
# 0  https://www.apartments.com/2372-beckwith-dr-in...    ze0jqwy    46218
# 3  https://www.apartments.com/7491-n-shadeland-av...    s34dq64    46250
# 4  https://www.apartments.com/nice-3-bedroom-ranc...    n669z9m    46237
# 5  https://www.apartments.com/1102-n-oakland-ave-...    c4kr5zf    46201
# 6  https://www.apartments.com/634-e-10th-st-india...    rl2dfp0    46202
#
#    monthly_rent  bedrooms  bathrooms  square_feet walk_score transit_score  \
# 0           751         2      1.000      679.000         25            33
# 3          1795         3      2.000     2500.000         54            33
# 4          1095         3      1.000     1439.000         29            32
# 5          1300         3      1.500     1500.000         67            38
# 6          1600         2      2.000     1400.000         74            53
#
#    deposit  latitude  longitude   pet           neighborhood
# 0      705    39.801    -86.126 0.000  Martindale-Brightwood
# 3     1795    39.890    -86.045   NaN        I-69 Fall Creek
# 4     1095    39.722    -86.121   NaN     University Heights
# 5      800    39.783    -86.113   NaN          Near Eastside
# 6     1600    39.781    -86.146   NaN           Chatham Arch

# %%
df_final.describe()
# Out:
#         zipcode  monthly_rent  bedrooms  bathrooms  square_feet  deposit  \
# count   973.000       973.000   973.000    973.000      954.000  973.000
# mean  46221.542      1394.843     2.006      1.571     1128.635 1265.683
# std      30.445       776.235     1.142      0.605      623.972  692.631
# min   46038.000       450.000     0.000      0.500       50.000  100.000
# 25%   46205.000       929.000     1.000      1.000      699.250  840.000
# 50%   46222.000      1250.000     2.000      1.500     1027.500 1175.000
# 75%   46237.000      1685.000     3.000      2.000     1400.000 1634.000
# max   46298.000     13124.000     5.000      4.000     9991.000 6472.000
#
#        latitude  longitude    pet
# count   973.000    973.000 43.000
# mean     39.793    -86.148  0.000
# std       0.077      0.088  0.000
# min      39.627    -86.341  0.000
# 25%      39.756    -86.204  0.000
# 50%      39.792    -86.146  0.000
# 75%      39.850    -86.092  0.000
# max      39.946    -85.950  0.000

# %%
ax, fig= plt.subplots(figsize=(10,20))

ax = sns.boxplot(data=df_final,  y='neighborhood', x='monthly_rent');

ax.set_title('Monthly Rent by Neigborhood')
plt.xticks(rotation=45);

# %%
ax, fig= plt.subplots(figsize=(12,6))

ax= sns.boxplot(data=df_final);

ax.set_title('Distribuation by Numeric Features')
plt.xticks(rotation=45);

# %%
ax, fig= plt.subplots(figsize=(12,6))

ax= sns.boxplot(data=df_final);


ax.set_title('Zoom in above graph')

ax.set_ylim(0,15000)
plt.xticks(rotation=45);

# %%
ax = sns.scatterplot(data=df_final, x='monthly_rent', y='bedrooms');
ax.set_title('Monthly Rent vs Bedrooms')
# Out:
# Text(0.5, 1.0, 'Monthly Rent vs Bedrooms')

# %%
ax = sns.scatterplot(data=df_final, x='monthly_rent', y='bathrooms');
ax.set_title('Monthly Rent vs Bathrooms')
# Out:
# Text(0.5, 1.0, 'Monthly Rent vs Bathrooms')

# %%
ax, fig= plt.subplots(figsize=(10,5))
ax = sns.barplot(data=df_final, y='monthly_rent', x='bedrooms',hue = 'bathrooms');


ax.set_title('Monthly Rent vs Bedrooms and Bathrooms')
ax.legend()

# %%
ax, fig= plt.subplots(figsize=(10,20))
sns.scatterplot(data=df_final, x='monthly_rent', y='neighborhood');

ax = sns.scatterplot(data=df_final, x='monthly_rent', y='bedrooms');
ax.set_title('Monthly Rent vs Neighborhood');

# %%
ax, fig= plt.subplots(figsize=(10,6))
ax= sns.heatmap(data=df_final.corr(), annot=True, linewidth=1);


ax.set_title('Correlation');
